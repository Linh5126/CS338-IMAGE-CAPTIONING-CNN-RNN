# %%
# %cd /kaggle/input/datasets/llnhins/cs338l
# Out:
# /kaggle/input/datasets/llnhins/cs338l

# %%
# !pip install ultralytics rouge-score nltk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !python train.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading: "https://download.pytorch.org/models/resnet101-cd907fc2.pth" to /root/.cache/torch/hub/checkpoints/resnet101-cd907fc2.pth
# 100%|█████████████████████████████████████████| 171M/171M [00:00<00:00, 181MB/s]
# [DualStreamEncoder] YOLO feature channels detected: 512
# Epoch: [0][0/938]	Loss 8.5547 (8.5547)	Top-5 Acc 0.568 (0.568)
# Epoch: [0][100/938]	Loss 5.4237 (5.9109)	Top-5 Acc 38.619 (35.543)
# Epoch: [0][200/938]	Loss 4.8969 (5.5070)	Top-5 Acc 47.745 (40.412)
# Epoch: [0][300/938]	Loss 4.8619 (5.2372)	Top-5 Acc 50.510 (44.331)
# Epoch: [0][400/938]	Loss 4.0673 (5.0452)	Top-5 Acc 60.833 (47.094)
# ...

# %%
# !python train.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading: "https://download.pytorch.org/models/resnet101-cd907fc2.pth" to /root/.cache/torch/hub/checkpoints/resnet101-cd907fc2.pth
# 100%|█████████████████████████████████████████| 171M/171M [00:01<00:00, 174MB/s]
# [DualStreamEncoder] YOLO feature channels: 512
# /kaggle/input/datasets/llnhins/cs338l/train.py:133: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=use_amp)
# /kaggle/input/datasets/llnhins/cs338l/train.py:211: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !pip install pycocoevalcap
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 18.3 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !python train_rl.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# /kaggle/input/datasets/llnhins/cs338l/train_rl.py:143: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=use_amp)
# Epoch: [7][0/938]	Batch Time 11.770	Reward Calc 0.074	Mean Reward -0.9506	Loss -18.6705 (-18.6705)
# Epoch: [7][100/938]	Batch Time 0.836	Reward Calc 0.058	Mean Reward -0.9868	Loss -21.0590 (-26.3169)
# Epoch: [7][200/938]	Batch Time 0.941	Reward Calc 0.066	Mean Reward -0.9800	Loss -24.1732 (-24.6835)
# Epoch: [7][300/938]	Batch Time 0.949	Reward Calc 0.054	Mean Reward -1.0911	Loss -20.9294 (-23.6244)
# ...

# %%
# %cd /kaggle/working/
# Out:
# /kaggle/working

# %%
from IPython.display import FileLink
# Nhớ đổi đúng tên file của bạn nhé
FileLink(r'BEST_checkpoint_dual_stream_lstm_adaptive_flickr8k_5_cap_per_img_5_min_word_freq.pth.tar')
# Out:
# /kaggle/working/BEST_checkpoint_dual_stream_lstm_adaptive_flickr8k_5_cap_per_img_5_min_word_freq.pth.tar
